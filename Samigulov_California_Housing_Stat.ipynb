# %% [markdown]
# <a href="https://colab.research.google.com/github/FractalHorns/Analytical-Work/blob/main/Samigulov_Homework9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Samigulov A.F. California Housing Stat.

# %%
data_file = 'sample_data/california_housing_test.csv'
datas = pd.read_csv(data_file)

# %%
datas
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# 9.1[40]: Работа в Google Colab. Файл california_housing_train.csv, который находится в папке sample_data.
# Для домов, где кол-во людей от 0 до 500 (population) вывести информацию о цене дома(median_house_value):
# максимальное значение, минимальное значение, среднее, медиану

# %%
datas[datas['population'] < 501]['median_house_value'].max()
# Out:
# 500001.0

# %%
datas[datas['population'] < 501]['median_house_value'].min()
# Out:
# 37500.0

# %%
datas[datas['population'] < 501]['median_house_value'].mean()
# Out:
# 190157.0918032787

# %%
datas[datas['population'] < 501]['median_house_value'].median()
# Out:
# 156300.0

# %% [markdown]
# 9.2[42]: Работа в Google Colab. Файл california_housing_train.csv, который находится в папке sample_data.
# Узнать какая максимальная households в зоне минимального значения population

# %%
Почему не работает данный код? 
##min_population = datas['population'].min()
##datas[datas['min_population'] == ['households'].max()]

# %%
## Рабочий вариант
datas[datas['population'] == datas['population'].min()]['households'].max()
# Out:
# 3.0
